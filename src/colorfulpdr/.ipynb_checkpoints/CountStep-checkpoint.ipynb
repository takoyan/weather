# %%
import pandas as pd
import numpy as np
from scipy import signal
import math

import matplotlib.pyplot as plt
import glob
import os

# %%
user='5NM4tiger'

data=pd.read_json("../../etc/no_header_pdr_raw_data/{}.json".format(user), orient='records', lines=True)
#data=pd.read_json('../../etc/step_num/5NM4tiger.csv', orient='records', lines=True)
labels=pd.read_csv('../../etc/label/{}.csv'.format(user), header=None)

acc_sencor=data[data['type']=='Accelerometer']

x, y, z=acc_sencor['x'], acc_sencor['y'], acc_sencor['z']

com_acc=[]
for value in zip(x, y, z):
    com_acc.append(math.sqrt(value[0]**2 + value[1]**2 + value[2]**2))
com_acc=com_acc[16000:20000]

# %%
unixTime=acc_sencor['unixTime']

a=[]
for t in unixTime:
    a.append(t//1000)

time_count=[]
for t in set(a):
    time_count.append(a.count(t))

# %%
N=len(com_acc)
dt=0.005
fc=3

t = np.arange(0, N*dt, dt)  # 時間軸
freq = np.linspace(0, 1.0/dt, N)  # 周波数軸

# %%
def getTimeLaps(labels):
    timeLaps=[]
    old_time, old_label=labels.loc[0][0], labels.loc[0][1]
    for time, label in zip(labels.iloc[:, 0], labels.iloc[:, 1]):
        if old_label != label:
            timeLaps+=[[old_time-25, time-25]]
            old_time=time
            old_label=label
    timeLaps+=[[old_time-25, time-25]]
    return timeLaps

# %%
def getLabelLaps(labels):
    labelLaps=[]
    old_time, old_label=labels.loc[0][0], labels.loc[0][1]
    labelLaps+=[old_label]
    for time, label in zip(labels.iloc[:, 0], labels.iloc[:, 1]):
        if old_label != label:
            labelLaps+=[label]
            old_time=time
            old_label=label
    labelLaps+=[label]
    return labelLaps

# %%
color_list={'m':'b', 's':'g', 'o':'r', 'no':'w'}

fig, ax = plt.subplots(figsize=(20, 5))
plt.plot(t, com_acc)

timeLaps=getTimeLaps(labels)
labelLaps=getLabelLaps(labels)

for time, label in zip(timeLaps, labelLaps):
    ax.axvspan(time[0], time[1], color=color_list[label], alpha=0.3)

plt.xlabel("Time", fontsize=12)
plt.ylabel("Amplitude", fontsize=12)
plt.grid()
plt.show()

# %%
color_list={'m':'b', 's':'g', 'o':'r', 'no':'w'}

fig, ax = plt.subplots(figsize=(20, 5))
plt.plot(t, com_acc)

timeLaps=getTimeLaps(labels)
labelLaps=getLabelLaps(labels)

#for time, label in zip(timeLaps, labelLaps):
#    ax.axvspan(time[0], time[1], color=color_list[label], alpha=0.3)

plt.xlabel("Time", fontsize=12)
plt.ylabel("Amplitude", fontsize=12)
plt.grid()
plt.show()

# %%
user='5NM4tiger'
a=pd.read_csv('../../etc/step_num/{}.csv'.format(user))
labels=pd.read_csv('../../etc/label/{}.csv'.format(user), header=None)

# %%
a=a['count_S']

# %%
color_list={'m':'b', 's':'g', 'o':'r', 'no':'w'}

fig, ax = plt.subplots(figsize=(20, 5))
plt.plot(range(0, len(a)), a)

timeLaps=getTimeLaps(labels)
labelLaps=getLabelLaps(labels)

for time, label in zip(timeLaps, labelLaps):
    ax.axvspan(time[0], time[1], color=color_list[label], alpha=0.3)

plt.xlabel("Time", fontsize=12)
plt.ylabel("Amplitude", fontsize=12)
plt.grid()
plt.show()

# %%
F = np.fft.fft(com_acc)
# 正規化 + 交流成分2倍
F = F/(N/2)
F[0] = F[0]/2

# %%
plt.plot(freq, np.abs(F), label='|F(k)|')
plt.xlabel('Frequency', fontsize=12)
plt.ylabel('Amplitude', fontsize=12)
plt.grid()

# %%
# 配列Fをコピー
F2 = F.copy()
# ローパスフィル処理（カットオフ周波数を超える帯域の周波数信号を0にする）
F2[(freq > fc)] = 0
# 高速逆フーリエ変換（時間信号に戻す）
f2 = np.fft.ifft(F2)

# %%
plt.plot(freq, np.abs(F2), label='|F(k)|')
plt.xlabel('Frequency', fontsize=12)
plt.ylabel('Amplitude', fontsize=12)
plt.grid()

# %%
# 高速逆フーリエ変換（時間信号に戻す）
f2 = np.fft.ifft(F2)

# 振幅を元のスケールに戻す
f2 = np.real(f2*N)

# %%
plt.plot(t, f2, label='f2(n)')
plt.xlabel("Time", fontsize=12)
plt.ylabel("Signal", fontsize=12)
plt.grid()
plt.show()

# %%
plt.plot(t, f2, label='f2(n)')
plt.xlabel("Time", fontsize=12)
plt.ylabel("Signal", fontsize=12)
plt.grid()
plt.show()

# %%
plt.plot(t, f2, label='f2(n)')
plt.xlabel("Time", fontsize=12)
plt.ylabel("Signal", fontsize=12)
plt.grid()
plt.show()

# %%
len([v for v in f2 if v>14])
# Out:
# 571

# %% [markdown]
# # SUB

# %%
data=pd.read_json("../../etc/no_header_pdr_raw_data/{}.json".format('5NM4tiger'), orient='records', lines=True)

# %%
unixTime=acc_sencor['unixTime']

a=[]
for t in unixTime:
    a.append(t//1000)

time_count=[]
for t in set(a):
    time_count.append(a.count(t))

# %% [markdown]
# # 合成加速度

# %%
data=pd.read_json("../../etc/no_header_pdr_raw_data/{}.json".format('5NM4tiger'), orient='records', lines=True)

acc_sencor=data[data['type']=='Accelerometer']

x, y, z=acc_sencor['x'], acc_sencor['y'], acc_sencor['z']

com_acc=[]
for value in zip(x, y, z):
    com_acc.append(math.sqrt(value[0]**2 + value[1]**2 + value[2]**2))

# %%
def getTimeCount(unixTime):
    a=[]
    for t in unixTime:
        a.append(t//1000)
        
    time_count=[]
    for t in set(a):
        time_count.append(a.count(t))
    return time_count

# %%
c=pd.read_json("../../etc/no_header_pdr_raw_data/{}.json".format('6NM9tsubouchi'), orient='records', lines=True)

# %% [markdown]
# # Main

# %%
ROUND=1000
dt=0.005
fc=5
w=1
SENSOR="Accelerometer"

for file in glob.glob("../../etc/label/*.csv"):
    file_name=os.path.basename(file).split(".csv")[0]
    new_df=pd.DataFrame()
    label=pd.read_csv("../../etc/label/{}.csv".format(file_name), header=None)    
    df=pd.read_json("../../etc/no_header_pdr_raw_data/{}.json".format(file_name), orient='records', lines=True)
    
    START_TIME=label[0][0]
    END_TIME=label[0][len(label)-1]
    count=0
    
    acc_sencor=df[df['type']==SENSOR]
    unixTime=acc_sencor['unixTime']
    x, y, z=acc_sencor['x'], acc_sencor['y'], acc_sencor['z']
    com_acc=[]
    for value in zip(x, y, z):
        com_acc.append(math.sqrt(value[0]**2 + value[1]**2 + value[2]**2))
    time_count=getTimeCount(unixTime)
    print(len(time_count))

    N=len(com_acc)
    t = np.arange(0, N*dt, dt)  # 時間軸
    freq = np.linspace(0, 1.0/dt, N)  # 周波数軸

    F = np.fft.fft(com_acc)
    # 正規化 + 交流成分2倍
    F = F/(N/2)
    F[0] = F[0]/2

    # 配列Fをコピー
    F2 = F.copy()
    # ローパスフィル処理（カットオフ周波数を超える帯域の周波数信号を0にする）
    F2[(freq > fc)] = 0
    # 高速逆フーリエ変換（時間信号に戻す）
    f2 = np.fft.ifft(F2)

    # 高速逆フーリエ変換（時間信号に戻す）
    f2 = np.fft.ifft(F2)
    # 振幅を元のスケールに戻す
    f2 = np.real(f2*N)
    for ti in range(START_TIME, END_TIME+1, 1):
        S=sum(time_count[:ti])
        f=f2[S-(200*w):S]
        #count_1=len([v for v in f if 0<=v and v<1])
        #count_2=len([v for v in f if 1<=v and v<2])
        #count_3=len([v for v in f if 2<=v and v<3])
        #count_4=len([v for v in f if 3<=v and v<4])
        #count_5=len([v for v in f if 4<=v and v<5])
        #count_6=len([v for v in f if 5<=v and v<6])
        #count_7=len([v for v in f if 6<=v and v<7])
        count_8=len([v for v in f if 8<=v])
        count_9=len([v for v in f if 9<=v])
        count_10=len([v for v in f if 10<=v])
        count_11=len([v for v in f if 11<=v])
        count_12=len([v for v in f if 12<=v])
        count_13=len([v for v in f if 13<=v])
        count_14=len([v for v in f if 14<=v])
        new_df=new_df.append({"user":file_name, "label":label[1][count], 
                              "count_8":count_8, "count_9":count_9, "count_10":count_10,
                              "count_11":count_11, "count_12":count_12, "count_13":count_13, "count_14":count_14}, 
                             ignore_index=True)
        count+=1
        
    new_df.to_csv("../../etc/step_num/{}.csv".format(file_name), index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-91def79cc7b2> in <module>
#       5 SENSOR="Accelerometer"
#       6
# ----> 7 for file in glob.glob("../../etc/label/*.csv"):
#       8     file_name=os.path.basename(file).split(".csv")[0]
#       9     new_df=pd.DataFrame()
#
# NameError: name 'glob' is not defined

# %%
data=pd.read_json("../../etc/no_header_pdr_raw_data/{}.json".format('5NM4tiger'), orient='records', lines=True)
label=pd.read_csv("../../etc/label/5NM4tiger.csv", header=None)

# %%
START_TIME=label[0][0]
END_TIME=label[0][len(label)-1]

# %%
acc_sencor=data[data['type']=='Accelerometer']
x, y, z=acc_sencor['x'], acc_sencor['y'], acc_sencor['z']
com_acc=[]
for value in zip(x, y, z):
    com_acc.append(math.sqrt(value[0]**2 + value[1]**2 + value[2]**2))

N=len(com_acc)
dt=0.005
fc=20

t = np.arange(0, N*dt, dt)  # 時間軸
freq = np.linspace(0, 1.0/dt, N)  # 周波数軸

F = np.fft.fft(com_acc)
# 正規化 + 交流成分2倍
F = F/(N/2)
F[0] = F[0]/2

# 配列Fをコピー
F2 = F.copy()
# ローパスフィル処理（カットオフ周波数を超える帯域の周波数信号を0にする）
F2[(freq > fc)] = 0
# 高速逆フーリエ変換（時間信号に戻す）
f2 = np.fft.ifft(F2)

# 高速逆フーリエ変換（時間信号に戻す）
f2 = np.fft.ifft(F2)
# 振幅を元のスケールに戻す
f2 = np.real(f2*N)

# %%
w=2
i=0
new_df=pd.DataFrame()
for ti in range(START_TIME, END_TIME+1, 1):
    f=f2[200*(ti-w):200*ti]
    count_11=len([v for v in f if v<11])
    count_1113=len([v for v in f if 11<=v and v<=13])
    count_13=len([v for v in f if 13<v])
    new_df=new_df.append({"U11":count_11, "11to13":count_1113, "O13":count_13}, ignore_index=True)

new_df.to_csv("../../etc/step_num/{}.csv".format('5NM4tiger'), index=False)

# %%
plt.plot(t, f2, label='f2(n)')
plt.xlabel("Time", fontsize=12)
plt.ylabel("Signal", fontsize=12)
plt.grid()
plt.show()

# %% [markdown]
# # Step + Peak

# %%
def getPeak(values, threshold):
    flag=False
    peakCount=0
    
    for value in values:
        if value > threshold and flag==False:
            flag=True
            peakCount+=1
        if value < threshold and flag==True:
            flag=False
    return peakCount

def getOPeak(values, Uthreshold):
    peakCount=0
    
    for index in range(1, len(values)-1):
        if values[index] > Uthreshold:
            if values[index] > values[index-1] and values[index+1] > values[index]:
                peakCount+=1
    return peakCount

def getUPeak(values, Othreshold):
    peakCount=0
    
    for index in range(1, len(values)-1):
        if values[index] < Othreshold:
            if values[index] > values[index-1] and values[index+1] > values[index]:
                peakCount+=1
    return peakCount

"""
def getPeak(values, Uthreshold, Othreshold):
    peakCount=0
    for index in range(1, len(values)-1, 1):
        if values[index] > Uthreshold and Othreshold > values[index]:
            if values[index] > values[index-1] and values[index+1] > values[index]:
                peakCount+=1
    return peakCount
"""
# Out:
# '\ndef getPeak(values, Uthreshold, Othreshold):\n    peakCount=0\n    for index in range(1, len(values)-1, 1):\n        if values[index] > Uthreshold and Othreshold > values[index]:\n            if values[index] > values[index-1] and values[index+1] > values[index]:\n                peakCount+=1\n    return peakCount\n'

# %%
ROUND=1000
dt=0.005
#fc1=20
fc2=3
w=2
SENSOR="Accelerometer"

for file in glob.glob("../../etc/label/*.csv")[38:39]:
    file_name=os.path.basename(file).split(".csv")[0]
    print(file_name)
    new_df=pd.DataFrame()
    label=pd.read_csv("../../etc/label/{}.csv".format(file_name), header=None)    
    df=pd.read_json("../../etc/no_header_pdr_raw_data/{}.json".format(file_name), orient='records', lines=True)
    
    START_TIME=label[0][0]
    END_TIME=label[0][len(label)-1]
    count=0
    
    acc_sencor=df[df['type']==SENSOR]
    unixTime=acc_sencor['unixTime']
    x, y, z=acc_sencor['x'], acc_sencor['y'], acc_sencor['z']
    com_acc=[]
    for value in zip(x, y, z):
        com_acc.append(math.sqrt(value[0]**2 + value[1]**2 + value[2]**2))
    time_count=getTimeCount(unixTime)

    N=len(com_acc)
    t = np.arange(0, N*dt, dt)  # 時間軸
    freq = np.linspace(0, 1.0/dt, N)  # 周波数軸

    F = np.fft.fft(com_acc)
    # 正規化 + 交流成分2倍
    F = F/(N/2)
    F[0] = F[0]/2

    """
    # 配列Fをコピー
    F2 = F.copy()
    # ローパスフィル処理（カットオフ周波数を超える帯域の周波数信号を0にする）
    F2[(freq > fc1)] = 0
    # 高速逆フーリエ変換（時間信号に戻す）
    f2 = np.fft.ifft(F2)

    # 高速逆フーリエ変換（時間信号に戻す）
    f2 = np.fft.ifft(F2)
    # 振幅を元のスケールに戻す
    f2 = np.real(f2*N)
    """
    
    F3 = F.copy()
    # ローパスフィル処理（カットオフ周波数を超える帯域の周波数信号を0にする）
    F3[(freq > fc2)] = 0
    # 高速逆フーリエ変換（時間信号に戻す）
    f3 = np.fft.ifft(F3)

    # 高速逆フーリエ変換（時間信号に戻す）
    f3 = np.fft.ifft(F3)
    # 振幅を元のスケールに戻す
    f3 = np.real(f3*N)
    
    for ti in range(START_TIME, END_TIME+1, 1):
        S=sum(time_count[:ti])
        #f=f2[S-(200*w):S]
        f=f3[S-(200*w):S]
        #count_1=len([v for v in f if 0<=v and v<1])
        #count_2=len([v for v in f if 1<=v and v<2])
        #count_3=len([v for v in f if 2<=v and v<3])
        #count_4=len([v for v in f if 3<=v and v<4])
        #count_5=len([v for v in f if 4<=v and v<5])
        #count_6=len([v for v in f if 5<=v and v<6])
        #count_7=len([v for v in f if 6<=v and v<7])
        #count_05=getPeak(f, 0.5)
        #count_06=getPeak(f, 0.6)
        #count_07=getPeak(f, 0.7)
        #count_08=getPeak(f, 0.8)
        #count_09=getPeak(f, 0.9)
        #count_1011=getPeak(ff, 11)
        count_S=getPeak(f, 10.5)
        count_M=getPeak(f, 11.25)
        #count_13=getPeak(f, 13)
        #count_14=getPeak(f, 14)
        new_df=new_df.append({"user":file_name, "label":label[1][count], 
                              "count_S":count_S, "count_M":count_M}, 
                             ignore_index=True)
        count+=1
        
    new_df.to_csv("../../etc/step_num/{}.csv".format(file_name), index=False)
# Out:
# 5NM4tiger
